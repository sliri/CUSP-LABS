# %% [markdown]
# ## Lab Experiment – 3: Frequency Characteristics of Capacitors
# #### Written by Liron Shekar

# %% [markdown]
# All labs from here :https://cusp.umn.edu/power-electronics/introduction-power-electronics
# <br>
# And here https://cusp.umn.edu/sites/cusp.dl.umn.edu/files/media/plecs_lab_manual.pdf

# %% [markdown]
# __1.+ 2.__
# <br>
# The -3dB cutoof frequency can be obtained from the equations.
# https://en.wikipedia.org/wiki/RLC_circuit
# $$ Y(s)=\frac{s}{s^2+2\alpha s + \omega_0^2}$$
# While
# $$ s=\sigma+j\omega $$
# $$ \omega _0=\frac{1}{\sqrt{LC}} $$
# $$ \alpha = \frac{1}{2}\frac{R}{L}$$
#
# One can calculate the known poles directley $s=\alpha\pm\sqrt{\alpha^2-\omega _0^2}$
# <br>
# https://en.wikipedia.org/wiki/Bode_plot
# <br>
# This is a second order system.
# At every pole the phase decrease the slope by 90$^\circ$ degrees per decade, beginning one decade before the pole and ending one decade after. Therefore the pole is exactley where the phase equals 45$^\circ$. The resulte are 190KHz and 370KHz.
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
#
# The cpmbined filter is a $4^{th}$ order system which is more complicated to analyze
# ![image-4.png](attachment:image-4.png)
